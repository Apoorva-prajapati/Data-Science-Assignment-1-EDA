# %% [markdown]
# # EDA:Movies Data
# Exploratory Data Analysis (EDA) refers to the method of studying and exploring record sets to apprehend their predominant traits, discover patterns.
# Movies data set contain names of movie ,in which year Release, Duration of the Movie, Ratings of the movie,Director .

# %%
#MOVIE DATASET
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv("movies_data.csv")
df.head()#give starting five rows
# Out:
#                                  Name  Year  Duration  \
# 0  #Gadhvi (He thought he was Gandhi)  2019       109
# 1                             #Yaaram  2019       110
# 2                ...Aur Pyaar Ho Gaya  1997       147
# 3                           ...Yahaan  2005       142
# 4                  ?: A Question Mark  2012        82
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 0                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 1            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 2     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 3        Drama, Romance, War     7.4   1086  Shoojit Sircar  Jimmy Sheirgill
# 4  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 0          Vivek Ghamande    Arvind Jangid
# 1              Ishita Raj  Siddhant Kapoor
# 2  Aishwarya Rai Bachchan    Shammi Kapoor
# ...

# %% [markdown]
# Attributes of Dataset
# Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3

# %%
df["Actor"]=df['Actor 1']+','+df['Actor 2']+','+df['Actor 3']#combine actor1,2,3

df.head()
# Out:
#                                  Name  Year  Duration  \
# 0  #Gadhvi (He thought he was Gandhi)  2019       109
# 1                             #Yaaram  2019       110
# 2                ...Aur Pyaar Ho Gaya  1997       147
# 3                           ...Yahaan  2005       142
# 4                  ?: A Question Mark  2012        82
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 0                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 1            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 2     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 3        Drama, Romance, War     7.4   1086  Shoojit Sircar  Jimmy Sheirgill
# 4  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3  \
# 0          Vivek Ghamande    Arvind Jangid
# 1              Ishita Raj  Siddhant Kapoor
# ...

# %%
df.shape#checking shape we do Data preprocessing
# Out:
# (5659, 11)

# %%
del df['Actor 1']

# %%
df.head()
# Out:
#                                  Name  Year  Duration  \
# 0  #Gadhvi (He thought he was Gandhi)  2019       109
# 1                             #Yaaram  2019       110
# 2                ...Aur Pyaar Ho Gaya  1997       147
# 3                           ...Yahaan  2005       142
# 4                  ?: A Question Mark  2012        82
#
#                        Genre  Rating  Votes        Director  \
# 0                      Drama     7.0      8   Gaurav Bakshi
# 1            Comedy, Romance     4.4     35      Ovais Khan
# 2     Comedy, Drama, Musical     4.7    827    Rahul Rawail
# 3        Drama, Romance, War     7.4   1086  Shoojit Sircar
# 4  Horror, Mystery, Thriller     5.6    326   Allyson Patel
#
#                   Actor 2          Actor 3  \
# 0          Vivek Ghamande    Arvind Jangid
# 1              Ishita Raj  Siddhant Kapoor
# 2  Aishwarya Rai Bachchan    Shammi Kapoor
# 3          Minissha Lamba   Yashpal Sharma
# 4          Muntazir Ahmad     Kiran Bhatia
#
# ...

# %%
del df['Actor 2']
del df['Actor 3']

# %%
df.head()
# Out:
#                                  Name  Year  Duration  \
# 0  #Gadhvi (He thought he was Gandhi)  2019       109
# 1                             #Yaaram  2019       110
# 2                ...Aur Pyaar Ho Gaya  1997       147
# 3                           ...Yahaan  2005       142
# 4                  ?: A Question Mark  2012        82
#
#                        Genre  Rating  Votes        Director  \
# 0                      Drama     7.0      8   Gaurav Bakshi
# 1            Comedy, Romance     4.4     35      Ovais Khan
# 2     Comedy, Drama, Musical     4.7    827    Rahul Rawail
# 3        Drama, Romance, War     7.4   1086  Shoojit Sircar
# 4  Horror, Mystery, Thriller     5.6    326   Allyson Patel
#
#                                              Actor
# 0        Rasika Dugal,Vivek Ghamande,Arvind Jangid
# 1               Prateik,Ishita Raj,Siddhant Kapoor
# 2  Bobby Deol,Aishwarya Rai Bachchan,Shammi Kapoor
# 3    Jimmy Sheirgill,Minissha Lamba,Yashpal Sharma
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name         object
# Year          int64
# Duration      int64
# Genre        object
# Rating      float64
# Votes         int64
# Director     object
# Actor        object
# dtype: object

# %%
df.nunique()#uniques values of dataset
# Out:
# Name        5385
# Year          91
# Duration     174
# Genre        376
# Rating        83
# Votes       2027
# Director    2431
# Actor       5604
# dtype: int64

# %%
#unique values in column 
for column in df.columns:
    unique_values=df[column].unique()
    print(f'Unique values in {column}:{unique_values}')
# Out:
# Unique values in Name:['#Gadhvi (He thought he was Gandhi)' '#Yaaram' '...Aur Pyaar Ho Gaya' ...
#  'Zulm Ki Zanjeer' 'Zulmi' 'Zulm-O-Sitam']
# Unique values in Year:[2019 1997 2005 2012 2014 2004 2016 1991 2018 2010 1958 2021 2017 2009
#  1993 2002 2008 1994 2007 2003 1998 1979 1974 2015 2006 1981 2020 1985
#  2013 2011 1988 1987 1999 1973 1968 1982 1977 1950 1969 1948 1990 1989
#  2001 2000 1953 1978 1963 1992 1976 1984 1986 1966 1975 1980 1967 1970
#  1952 1972 1971 1964 1954 1962 1957 1965 1996 1995 1956 1955 1936 1983
#  1951 1961 1959 1949 1960 1946 1940 1945 1938 1941 1942 1935 1937 1947
#  1931 1933 1943 1944 1932 1939 1934]
# Unique values in Duration:[109 110 147 142  82 116  96 120 161 166 102  87 132 105 146 168 158 126
#   94 138 124 144 157 136 107 113  80 122 149 148 130 121 188 115 103 114
#  170 100  99 140 128  93 125 145  75 111 134 104  92 137 127 119 135  90
#  150 151  95 112 143 177 117 123  72 154 175 153  78 139 133 180  46 164
# ...

# %%
#dulpicate
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# if we have duplicate df=df.drop_duplicates()

# %%
df.isnull()#check null values
# Out:
#        Name   Year  Duration  Genre  Rating  Votes  Director  Actor
# 0     False  False     False  False   False  False     False  False
# 1     False  False     False  False   False  False     False  False
# 2     False  False     False  False   False  False     False  False
# 3     False  False     False  False   False  False     False  False
# 4     False  False     False  False   False  False     False  False
# ...     ...    ...       ...    ...     ...    ...       ...    ...
# 5654  False  False     False  False   False  False     False  False
# 5655  False  False     False  False   False  False     False  False
# 5656  False  False     False  False   False  False     False  False
# 5657  False  False     False  False   False  False     False  False
# 5658  False  False     False  False   False  False     False  False
#
# [5659 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor       0
# dtype: int64

# %% [markdown]
# # Descriptive Analysis
# 1.Univariate Analysis

# %%
plt.figure(figsize=(15, 8))
plt.title("Movies")
sns.countplot(x='Year', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title("Movie ")
sns.histplot(x='Rating', data=df, kde=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 2. Bivariate Analysis

# %%
sns.jointplot(x=df['Year'], y=df['Duration'], kind='reg')
plt.show()

# %%
ax = sns.jointplot(x=df['Year'], y=df['Duration'], kind='kde')
plt.show()

# %%
pairs = df[['Name', 'Year', 'Duration', 'Genre','Rating','Votes','Director','Actor']]
sns.pairplot(pairs)
plt.show()

# %% [markdown]
# Heatmap
